# %%
#Loading data
import pandas as pd 
df = pd.read_csv('Data/Movies_dataset.csv')

# %%
#understanding data
df
# Out:
#           id             original_title original_language  \
# 0        278   The Shawshank Redemption                en
# 1        238              The Godfather                en
# 2        240      The Godfather Part II                en
# 3        424           Schindler's List                en
# 4        389               12 Angry Men                en
# ...      ...                        ...               ...
# 9995  226486                      Tammy                en
# 9996   47964     A Good Day to Die Hard                en
# 9997  203835  Amityville: The Awakening                en
# 9998   43552    Vanishing on 7th Street                en
# 9999   80304           Casa de Mi Padre                en
#
#                           genre  \
# 0                  Drama, Crime
# 1                  Drama, Crime
# 2                  Drama, Crime
# 3           Drama, History, War
# 4                         Drama
# ...                         ...
# 9995                     Comedy
# ...

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.columns
# Out:
# Index(['id', 'original_title', 'original_language', 'genre', 'overview',
#        'popularity', 'vote_count', 'vote_average', 'release_date'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of           id             original_title original_language  \
# 0        278   The Shawshank Redemption                en
# 1        238              The Godfather                en
# 2        240      The Godfather Part II                en
# 3        424           Schindler's List                en
# 4        389               12 Angry Men                en
# ...      ...                        ...               ...
# 9995  226486                      Tammy                en
# 9996   47964     A Good Day to Die Hard                en
# 9997  203835  Amityville: The Awakening                en
# 9998   43552    Vanishing on 7th Street                en
# 9999   80304           Casa de Mi Padre                en
#
#                           genre  \
# 0                  Drama, Crime
# 1                  Drama, Crime
# 2                  Drama, Crime
# 3           Drama, History, War
# 4                         Drama
# ...                         ...
# ...

# %%
df.dtypes
# Out:
# id                     int64
# original_title        object
# original_language     object
# genre                 object
# overview              object
# popularity           float64
# vote_count             int64
# vote_average         float64
# release_date          object
# dtype: object

# %%
#data cleaning
df.isna().sum()
# Out:
# id                   0
# original_title       0
# original_language    0
# genre                3
# overview             1
# popularity           0
# vote_count           0
# vote_average         0
# release_date         2
# dtype: int64

# %%
df.isna().mean() * 100
# Out:
# id                   0.00
# original_title       0.00
# original_language    0.00
# genre                0.03
# overview             0.01
# popularity           0.00
# vote_count           0.00
# vote_average         0.00
# release_date         0.02
# dtype: float64

# %%
df[df.isna().any(axis=1)]
# Out:
#            id original_title original_language           genre  \
# 3706   357953         Return                en             NaN
# 5327   733668         Return                hy             NaN
# 5538   348877         Return                en             NaN
# 5591  1198870         Return                en          Horror
# 6579  1045781            Ret                tr  Drama, History
#
#                                                overview  popularity  \
# 3706  Return is a methodical construction of the app...      3.5457
# 5327  Eyüp decides to cross mount Ararat looking for...      0.3483
# 5538  Static images of an old country house are comb...      0.2069
# 5591  A girl is at school. Suddenly it's as if she c...      2.2790
# 6579                                                NaN      0.2431
#
#       vote_count  vote_average release_date
# 3706         645         6.952   1975-09-04
# 5327         423         6.638          NaN
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df.duplicated(keep = False)]
# Out:
#           id  original_title original_language                     genre  \
# 1559  319373              あん                ja                     Drama
# 1560  319373              あん                ja                     Drama
# 1979   58857          十三人の刺客                ja  Adventure, Drama, Action
# 1980   58857          十三人の刺客                ja  Adventure, Drama, Action
# 2059   82695  Les Misérables                en            History, Drama
# 2060   82695  Les Misérables                en            History, Drama
#
#                                                overview  popularity  \
# 1559  The master of a dorayaki pastry store hires a ...      4.0988
# 1560  The master of a dorayaki pastry store hires a ...      4.0988
# 1979  A bravado period action film set at the end of...      5.1987
# 1980  A bravado period action film set at the end of...      5.1987
# 2059  An adaptation of the successful stage musical ...      7.3351
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           id             original_title original_language  \
# 0        278   The Shawshank Redemption                en
# 1        238              The Godfather                en
# 2        240      The Godfather Part II                en
# 3        424           Schindler's List                en
# 4        389               12 Angry Men                en
# ...      ...                        ...               ...
# 9995  226486                      Tammy                en
# 9996   47964     A Good Day to Die Hard                en
# 9997  203835  Amityville: The Awakening                en
# 9998   43552    Vanishing on 7th Street                en
# 9999   80304           Casa de Mi Padre                en
#
#                           genre  \
# 0                  Drama, Crime
# 1                  Drama, Crime
# 2                  Drama, Crime
# 3           Drama, History, War
# 4                         Drama
# ...                         ...
# 9995                     Comedy
# ...

# %%
df.head(40)
# Out:
#         id                                     original_title  \
# 0      278                           The Shawshank Redemption
# 1      238                                      The Godfather
# 2      240                              The Godfather Part II
# 3      424                                   Schindler's List
# 4      389                                       12 Angry Men
# 5      129                                           千と千尋の神隠し
# 6      155                                    The Dark Knight
# 7    19404                       दिलवाले दुल्हनिया ले जायेंगे
# 8      497                                     The Green Mile
# 9   496243                                                기생충
# 10     122      The Lord of the Rings: The Return of the King
# 11     680                                       Pulp Fiction
# 12  372058                                              君の名は。
# 13     429                    Il buono, il brutto, il cattivo
# ...

# %%
#Data is very much clean and ready for drawing out conclusions 
#Which language movies are most common?
#How many langauges are in this data set 
#How many Hindi films are in top 100 list
#How many japanese films are in top 100 list
#Which genre has the highest rated films
#How many movies before 1999 are in the top 100
#average vote of top 100 movies
#average vote of all the movies
#how many movies are from crime genre
#what is popularity of highest rated Hindi movie
#What is the vote count of highest rated japanese movie
#How many movies have a rating above 8?
#What is the median vs mean rating?
#Do more popular movies always have higher ratings?
#Which popular movies have surprisingly low ratings?
#Which less popular movies have very high ratings?
#How does popularity change over release years?
#Is popularity skewed toward newer movies?
#Do multi-genre movies get higher ratings?
#Which genre has the most underrated movies?
#Which languages have the highest vote participation?
#movie with highest rating and lowest popularity
#DATA DRIVEN MOVIE RECOMMENDATION SYSTEM
